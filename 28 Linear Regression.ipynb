# %%
import pandas as pd
import numpy as np
import scipy
import statsmodels.api as sm
from statsmodels.formula.api import ols

import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_excel('reg1.xlsx')
data
# Out:
#    Hydrocarbon Level  Purity
# 0               0.99   90.01
# 1               1.02   89.05
# 2               1.15   91.43
# 3               1.29   93.74
# 4               1.46   96.73
# 5               1.36   94.45
# 6               0.87   87.59
# 7               1.23   91.77
# 8               1.55   99.42
# 9               1.40   93.65

# %%
x = data['Hydrocarbon Level']
y = data['Purity']
plt.figure()
sns.regplot(x=x,y=y, fit_reg=True)
plt.scatter(np.mean(x), np.mean(y), color="green")
